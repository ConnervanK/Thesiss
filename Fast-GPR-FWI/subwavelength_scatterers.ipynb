# %%
import os
import time
import torch
from src.compute import compute
from src.multiscale import apply_filter
import src.visualization as visualization
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage import filters
import matplotlib.pyplot as plt

device = torch.device('cuda')

# 1. GENERATE SUBWAVELENGTH SCATTERER MODEL
# Background permittivity = 5.0, conductivity = 0.001
ep_true = np.ones((200, 100)) * 5.0
se_true = np.ones((200, 100)) * 0.001

# Add subwavelength scatterers
# For f=1e8 (100 MHz), lambda in eps=5 is ~1.34 m. 
# Grid spacing dx = 0.05m -> wavelength is ~27 cells.
# A size of 2x2 cells (0.1m) is roughly lambda/13, which is subwavelength.
scatterer_positions = [
    (50, 40),
    (100, 40),
    (150, 40),
    (100, 70)
]

for (cx, cy) in scatterer_positions:
    # Set to air void equivalent (eps=1, sigma=0)
    ep_true[cx-1:cx+2, cy-1:cy+2] = 1.0  
    se_true[cx-1:cx+2, cy-1:cy+2] = 0.5

# Apply padding for boundaries
padded_ep = np.zeros((220, 120))
padded_ep[10:-10, 10:-10] = ep_true
padded_ep[:10, 10:-10] = ep_true[0:1, :].repeat(10, axis=0)
padded_ep[-10:, 10:-10] = ep_true[-1:, :].repeat(10, axis=0)
padded_ep[:, :10] = padded_ep[:, 10:11].repeat(10, axis=1)
padded_ep[:, -10:] = padded_ep[:, -11:-10].repeat(10, axis=1)
ep_t = torch.tensor(padded_ep, device=device).unsqueeze(-1)

padded_s = np.zeros((220, 120))
padded_s[10:-10, 10:-10] = se_true
padded_s[:10, 10:-10] = se_true[0:1, :].repeat(10, axis=0)
padded_s[-10:, 10:-10] = se_true[-1:, :].repeat(10, axis=0)
padded_s[:, :10] = padded_s[:, 10:11].repeat(10, axis=1)
padded_s[:, -10:] = padded_s[:, -11:-10].repeat(10, axis=1)
se_t = torch.tensor(padded_s, device=device).unsqueeze(-1)
mr_t = torch.ones_like(ep_t)
sm_t = torch.zeros_like(ep_t)

# Initial models for inversion: Homogeneous background
ep_init = torch.ones_like(ep_t) * 5.0
se_init = torch.ones_like(se_t) * 0.001
epg = ep_init[10:-10, 10:-10, 0]
sig = se_init[10:-10, 10:-10, 0]

erdir = 'pred_erdp_subw'
if not os.path.exists(erdir):
    os.makedirs(erdir)

np.save(erdir+'/epg.npy', epg.cpu().numpy())
np.save(erdir+'/sig.npy', sig.cpu().numpy())
np.save(erdir+'/se_true.npy', se_true)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))  
im1 = axes[0].imshow(ep_t[:, :, 0].cpu().numpy(),
                     cmap='viridis',
                     interpolation='nearest',
                     aspect='equal')
cbar1 = plt.colorbar(im1, ax=axes[0])
axes[0].set_title('Relative permittivity')
axes[0].set_xlabel('Distance (grid)')
axes[0].set_ylabel('Depth (grid)')

im2 = axes[1].imshow(se_t[:, :, 0].cpu().numpy(),
                     cmap='viridis',
                     interpolation='nearest',
                     aspect='equal')
cbar2 = plt.colorbar(im2, ax=axes[1])
cbar2.set_label('S/m')
axes[1].set_title('Conductivity')
axes[1].set_xlabel('Distance (grid)')
axes[1].set_ylabel('Depth (grid)')

plt.tight_layout()
plt.show()

dx = torch.tensor(0.05)
nx= torch.tensor(220)
ny= torch.tensor(120)
nz= torch.tensor(1)
dt=1e-10
time_windows = torch.tensor(1e-7)
source = ['hertzian', 'z']

nsrc = 1
nrx = 200
source_step = torch.tensor([0.25, 0, 0])
receiver_step = torch.tensor([0.05, 0, 0])
source_location = torch.tensor([0.5, 0.50, 0])
receiver_location = torch.tensor([0.5, 5.50, 0]) 

step = 40
source_amplitudes = ['ricker', 1, 1e8]
n_epochs = 100

Target_freq=[1e8]

pmlthick=10
observed_data, tt = compute(device, dx, ny, nx, nz, source, source_amplitudes, step, ep_t,
                           se_t, mr_t, nsrc, nrx, time_windows=time_windows,dt=dt,
                           source_location=source_location, source_step=source_step,
                           receiver_location=receiver_location, receiver_step=receiver_step,
                           pmlthick=pmlthick, Fixedreceiver=True
                            )

pdata=observed_data[20,:,:].cpu().numpy()

# %%
er=ep_init.clone()
se=se_init.clone()

mr = mr_t.clone()

optimiser_phase1 = torch.optim.Adam([
    {'params': er, 'lr': 0.2},
])

optimiser_phase2 = torch.optim.Adam([
    {'params': er, 'lr': 0.1},
    {'params': se, 'lr': 0.0001}
])
phase1_epochs = 50 
losses = []
Change_freq=1000

loss_fnmse = torch.nn.MSELoss()
loss_fnl1= torch.nn.L1Loss()

start_time = time.time()

for epoch in range(n_epochs):
    if epoch < phase1_epochs:
        current_optimizer = optimiser_phase1
        se.requires_grad = False 
        er.requires_grad = True  
    else:
        current_optimizer = optimiser_phase2
        se.requires_grad = True    
        er.requires_grad = True   
    
    epoch_start = time.time()
    if 'Target_freq' in globals():
        n = epoch // Change_freq
        if n >= len(Target_freq) or len(Target_freq)==1:
            freq = source_amplitudes[2]
            observed_data1=observed_data
        else:
            freq = Target_freq[n]
            observed_data1= apply_filter(observed_data.detach(),1/dt,freq)

    
    current_optimizer.zero_grad()

    result, tt = compute(device, dx, ny, nx, nz, source, source_amplitudes, step, er,
                           se, mr, nsrc, nrx, time_windows=time_windows,dt=dt,
                           source_location=source_location, source_step=source_step,
                           receiver_location=receiver_location, receiver_step=receiver_step,
                           pmlthick=pmlthick, Fixedreceiver=True,freq=freq
                            )
  
    loss = loss_fnl1(result, observed_data) * 100

    loss.backward()
    if er.requires_grad:
        er.grad[:, :pmlthick, :] = 0
        er.grad[:, -pmlthick:, :] = 0
    if se.requires_grad:
        se.grad[:, :pmlthick, :] = 0
        se.grad[:, -pmlthick:, :] = 0
    current_optimizer.step()
    losses.append(loss.item())  # 记录loss值
    epoch_time = time.time() - epoch_start  # 计算当前 epoch 用时
    total_time = time.time() - start_time  # 计算总用时
    
    # Optional SSIM calculation (only works if visualisation contains calculation for identical shapes)
    if 'calculatessim' in dir(visualization):
        ssim_value = visualization.calculatessim(er[pmlthick:-pmlthick, pmlthick:-pmlthick, :], ep_t[pmlthick:-pmlthick, pmlthick:-pmlthick, :])
    
    print(f"Epoch {epoch}, Loss: {loss.item():.6f}, Freq: {freq/1000000:.0f}MHz, Epoch Time: {epoch_time:.2f}s, Total Time: {total_time:.2f}s")
    save_epoch=10
    if epoch % save_epoch == 0:
        er_ = er[pmlthick:-pmlthick, pmlthick:-pmlthick, :]
        se_ = se[pmlthick:-pmlthick, pmlthick:-pmlthick, :]
        np.save(erdir + "/" + str(int(epoch / save_epoch)) + "sigma.npy", se_.cpu().detach().numpy())
        np.save(erdir + "/" + str(int(epoch /save_epoch)) + "epsilon.npy", er_.cpu().detach().numpy())
    
    with torch.no_grad():
        se.data.clamp_(min=0.000, max=0.006)
        er.data.clamp_(min=1)

    print("-----------")
# Out:
# Total variation regularization took 0.8618 seconds.
# Epoch 0, Loss: 40.844715, Freq: 100MHz, Epoch Time: 6.45s, Total Time: 6.45s
# -----------
# Total variation regularization took 0.8677 seconds.
# Epoch 1, Loss: 63.174618, Freq: 100MHz, Epoch Time: 4.17s, Total Time: 10.62s
# -----------
# Total variation regularization took 0.8600 seconds.
# Epoch 2, Loss: 52.215939, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 17.04s
# -----------
# Total variation regularization took 0.8602 seconds.
# Epoch 3, Loss: 36.151985, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 21.20s
# -----------
# Total variation regularization took 0.8740 seconds.
# Epoch 4, Loss: 40.995380, Freq: 100MHz, Epoch Time: 6.46s, Total Time: 27.65s
# -----------
# Total variation regularization took 0.8633 seconds.
# Epoch 5, Loss: 43.998604, Freq: 100MHz, Epoch Time: 4.16s, Total Time: 31.81s
# -----------
# Total variation regularization took 0.8903 seconds.
# Epoch 6, Loss: 39.342422, Freq: 100MHz, Epoch Time: 6.43s, Total Time: 38.25s
# -----------
# Total variation regularization took 0.8594 seconds.
# Epoch 7, Loss: 34.815601, Freq: 100MHz, Epoch Time: 4.14s, Total Time: 42.39s
# -----------
# Total variation regularization took 0.8681 seconds.
# Epoch 8, Loss: 34.814159, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 48.81s
# -----------
# Total variation regularization took 0.8634 seconds.
# Epoch 9, Loss: 35.002552, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 52.96s
# -----------
# Total variation regularization took 0.8608 seconds.
# Epoch 10, Loss: 33.625263, Freq: 100MHz, Epoch Time: 6.44s, Total Time: 59.40s
# -----------
# Total variation regularization took 0.8670 seconds.
# Epoch 11, Loss: 32.133648, Freq: 100MHz, Epoch Time: 4.16s, Total Time: 63.56s
# -----------
# Total variation regularization took 0.8548 seconds.
# Epoch 12, Loss: 32.272957, Freq: 100MHz, Epoch Time: 6.41s, Total Time: 69.97s
# -----------
# Total variation regularization took 0.8662 seconds.
# Epoch 13, Loss: 30.373478, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 74.12s
# -----------
# Total variation regularization took 0.8538 seconds.
# Epoch 14, Loss: 28.919256, Freq: 100MHz, Epoch Time: 6.40s, Total Time: 80.53s
# -----------
# Total variation regularization took 0.8799 seconds.
# Epoch 15, Loss: 29.785198, Freq: 100MHz, Epoch Time: 4.20s, Total Time: 84.73s
# -----------
# Total variation regularization took 0.8557 seconds.
# Epoch 16, Loss: 29.000858, Freq: 100MHz, Epoch Time: 6.40s, Total Time: 91.13s
# -----------
# Total variation regularization took 0.8573 seconds.
# Epoch 17, Loss: 27.313068, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 95.28s
# -----------
# Total variation regularization took 0.8554 seconds.
# Epoch 18, Loss: 27.454847, Freq: 100MHz, Epoch Time: 6.41s, Total Time: 101.69s
# -----------
# Total variation regularization took 0.8549 seconds.
# Epoch 19, Loss: 27.110949, Freq: 100MHz, Epoch Time: 4.14s, Total Time: 105.84s
# -----------
# Total variation regularization took 0.8638 seconds.
# Epoch 20, Loss: 26.966030, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 112.26s
# -----------
# Total variation regularization took 0.8619 seconds.
# Epoch 21, Loss: 26.833652, Freq: 100MHz, Epoch Time: 4.18s, Total Time: 116.44s
# -----------
# Total variation regularization took 0.8541 seconds.
# Epoch 22, Loss: 25.825483, Freq: 100MHz, Epoch Time: 6.41s, Total Time: 122.85s
# -----------
# Total variation regularization took 0.8570 seconds.
# Epoch 23, Loss: 25.511423, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 127.01s
# -----------
# Total variation regularization took 0.8562 seconds.
# Epoch 24, Loss: 25.174068, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 133.43s
# -----------
# Total variation regularization took 0.8537 seconds.
# Epoch 25, Loss: 25.121626, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 137.58s
# -----------
# Total variation regularization took 0.8668 seconds.
# Epoch 26, Loss: 24.556997, Freq: 100MHz, Epoch Time: 6.43s, Total Time: 144.01s
# -----------
# Total variation regularization took 0.8643 seconds.
# Epoch 27, Loss: 23.928408, Freq: 100MHz, Epoch Time: 4.17s, Total Time: 148.17s
# -----------
# Total variation regularization took 0.8625 seconds.
# Epoch 28, Loss: 23.555107, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 154.60s
# -----------
# Total variation regularization took 0.8556 seconds.
# Epoch 29, Loss: 23.223593, Freq: 100MHz, Epoch Time: 4.16s, Total Time: 158.75s
# -----------
# Total variation regularization took 0.8588 seconds.
# Epoch 30, Loss: 22.803099, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 165.18s
# -----------
# Total variation regularization took 0.8559 seconds.
# Epoch 31, Loss: 22.441675, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 169.33s
# -----------
# Total variation regularization took 0.8628 seconds.
# Epoch 32, Loss: 22.025223, Freq: 100MHz, Epoch Time: 6.44s, Total Time: 175.77s
# -----------
# Total variation regularization took 0.8576 seconds.
# Epoch 33, Loss: 22.145002, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 179.93s
# -----------
# Total variation regularization took 0.8566 seconds.
# Epoch 34, Loss: 21.748249, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 186.35s
# -----------
# Total variation regularization took 0.8568 seconds.
# Epoch 35, Loss: 21.599325, Freq: 100MHz, Epoch Time: 4.16s, Total Time: 190.50s
# -----------
# Total variation regularization took 0.8560 seconds.
# Epoch 36, Loss: 21.262989, Freq: 100MHz, Epoch Time: 6.40s, Total Time: 196.91s
# -----------
# Total variation regularization took 0.8569 seconds.
# Epoch 37, Loss: 21.164270, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 201.06s
# -----------
# Total variation regularization took 0.8542 seconds.
# Epoch 38, Loss: 20.881618, Freq: 100MHz, Epoch Time: 6.44s, Total Time: 207.51s
# -----------
# Total variation regularization took 0.8570 seconds.
# Epoch 39, Loss: 20.732546, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 211.66s
# -----------
# Total variation regularization took 0.8623 seconds.
# Epoch 40, Loss: 20.453363, Freq: 100MHz, Epoch Time: 6.41s, Total Time: 218.07s
# -----------
# Total variation regularization took 0.8535 seconds.
# Epoch 41, Loss: 20.455572, Freq: 100MHz, Epoch Time: 4.17s, Total Time: 222.24s
# -----------
# Total variation regularization took 0.8556 seconds.
# Epoch 42, Loss: 20.227371, Freq: 100MHz, Epoch Time: 6.40s, Total Time: 228.65s
# -----------
# Total variation regularization took 0.8676 seconds.
# Epoch 43, Loss: 20.082619, Freq: 100MHz, Epoch Time: 4.16s, Total Time: 232.81s
# -----------
# Total variation regularization took 0.8608 seconds.
# Epoch 44, Loss: 19.876411, Freq: 100MHz, Epoch Time: 6.42s, Total Time: 239.23s
# -----------
# Total variation regularization took 0.8578 seconds.
# Epoch 45, Loss: 19.849167, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 243.38s
# -----------
# Total variation regularization took 0.8572 seconds.
# Epoch 46, Loss: 19.617914, Freq: 100MHz, Epoch Time: 6.41s, Total Time: 249.79s
# -----------
# Total variation regularization took 0.8577 seconds.
# Epoch 47, Loss: 19.577274, Freq: 100MHz, Epoch Time: 4.15s, Total Time: 253.94s
# -----------
# Total variation regularization took 0.8541 seconds.
# Epoch 48, Loss: 19.411688, Freq: 100MHz, Epoch Time: 6.41s, Total Time: 260.35s
# -----------
# Total variation regularization took 0.8609 seconds.
# Epoch 49, Loss: 19.361664, Freq: 100MHz, Epoch Time: 4.17s, Total Time: 264.52s
# -----------
# Total variation regularization took 1.7171 seconds.
# Epoch 50, Loss: 19.187538, Freq: 100MHz, Epoch Time: 7.90s, Total Time: 272.43s
# -----------
# Total variation regularization took 1.7164 seconds.
# Epoch 51, Loss: 33.530804, Freq: 100MHz, Epoch Time: 5.14s, Total Time: 277.57s
# -----------
# Total variation regularization took 1.7233 seconds.
# Epoch 52, Loss: 29.606009, Freq: 100MHz, Epoch Time: 7.92s, Total Time: 285.49s
# -----------
# Total variation regularization took 1.7199 seconds.
# Epoch 53, Loss: 21.462252, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 290.65s
# -----------
# Total variation regularization took 1.7248 seconds.
# Epoch 54, Loss: 20.969114, Freq: 100MHz, Epoch Time: 8.00s, Total Time: 298.65s
# -----------
# Total variation regularization took 1.7210 seconds.
# Epoch 55, Loss: 23.010933, Freq: 100MHz, Epoch Time: 5.17s, Total Time: 303.82s
# -----------
# Total variation regularization took 1.7182 seconds.
# Epoch 56, Loss: 20.908684, Freq: 100MHz, Epoch Time: 7.84s, Total Time: 311.66s
# -----------
# Total variation regularization took 1.7322 seconds.
# Epoch 57, Loss: 18.068892, Freq: 100MHz, Epoch Time: 5.17s, Total Time: 316.83s
# -----------
# Total variation regularization took 1.7363 seconds.
# Epoch 58, Loss: 18.549875, Freq: 100MHz, Epoch Time: 7.87s, Total Time: 324.70s
# -----------
# Total variation regularization took 1.7208 seconds.
# Epoch 59, Loss: 19.320244, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 329.85s
# -----------
# Total variation regularization took 1.7136 seconds.
# Epoch 60, Loss: 17.958181, Freq: 100MHz, Epoch Time: 7.85s, Total Time: 337.69s
# -----------
# Total variation regularization took 1.7121 seconds.
# Epoch 61, Loss: 16.240591, Freq: 100MHz, Epoch Time: 5.16s, Total Time: 342.86s
# -----------
# Total variation regularization took 1.7256 seconds.
# Epoch 62, Loss: 16.290955, Freq: 100MHz, Epoch Time: 7.86s, Total Time: 350.73s
# -----------
# Total variation regularization took 1.7206 seconds.
# Epoch 63, Loss: 16.786201, Freq: 100MHz, Epoch Time: 5.16s, Total Time: 355.89s
# -----------
# Total variation regularization took 1.7093 seconds.
# Epoch 64, Loss: 15.948658, Freq: 100MHz, Epoch Time: 7.84s, Total Time: 363.73s
# -----------
# Total variation regularization took 1.7096 seconds.
# Epoch 65, Loss: 15.032487, Freq: 100MHz, Epoch Time: 5.13s, Total Time: 368.87s
# -----------
# Total variation regularization took 1.7126 seconds.
# Epoch 66, Loss: 14.967028, Freq: 100MHz, Epoch Time: 7.84s, Total Time: 376.71s
# -----------
# Total variation regularization took 1.7183 seconds.
# Epoch 67, Loss: 14.809330, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 381.86s
# -----------
# Total variation regularization took 1.7119 seconds.
# Epoch 68, Loss: 14.381866, Freq: 100MHz, Epoch Time: 7.86s, Total Time: 389.72s
# -----------
# Total variation regularization took 1.7165 seconds.
# Epoch 69, Loss: 14.060244, Freq: 100MHz, Epoch Time: 5.14s, Total Time: 394.87s
# -----------
# Total variation regularization took 1.7250 seconds.
# Epoch 70, Loss: 13.591234, Freq: 100MHz, Epoch Time: 7.87s, Total Time: 402.74s
# -----------
# Total variation regularization took 1.7309 seconds.
# Epoch 71, Loss: 13.494555, Freq: 100MHz, Epoch Time: 5.14s, Total Time: 407.88s
# -----------
# Total variation regularization took 1.7153 seconds.
# Epoch 72, Loss: 13.377047, Freq: 100MHz, Epoch Time: 7.86s, Total Time: 415.74s
# -----------
# Total variation regularization took 1.7181 seconds.
# Epoch 73, Loss: 12.758734, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 420.89s
# -----------
# Total variation regularization took 1.7201 seconds.
# Epoch 74, Loss: 12.917380, Freq: 100MHz, Epoch Time: 7.86s, Total Time: 428.75s
# -----------
# Total variation regularization took 1.7124 seconds.
# Epoch 75, Loss: 12.851894, Freq: 100MHz, Epoch Time: 5.13s, Total Time: 433.88s
# -----------
# Total variation regularization took 1.7335 seconds.
# Epoch 76, Loss: 12.107456, Freq: 100MHz, Epoch Time: 7.87s, Total Time: 441.75s
# -----------
# Total variation regularization took 1.7128 seconds.
# Epoch 77, Loss: 12.495063, Freq: 100MHz, Epoch Time: 5.16s, Total Time: 446.91s
# -----------
# Total variation regularization took 1.7156 seconds.
# Epoch 78, Loss: 12.520494, Freq: 100MHz, Epoch Time: 7.85s, Total Time: 454.76s
# -----------
# Total variation regularization took 1.7272 seconds.
# Epoch 79, Loss: 12.095743, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 459.91s
# -----------
# Total variation regularization took 1.7167 seconds.
# Epoch 80, Loss: 11.771731, Freq: 100MHz, Epoch Time: 7.86s, Total Time: 467.76s
# -----------
# Total variation regularization took 1.7317 seconds.
# Epoch 81, Loss: 11.727645, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 472.92s
# -----------
# Total variation regularization took 1.7372 seconds.
# Epoch 82, Loss: 11.601665, Freq: 100MHz, Epoch Time: 7.95s, Total Time: 480.87s
# -----------
# Total variation regularization took 1.7346 seconds.
# Epoch 83, Loss: 11.236607, Freq: 100MHz, Epoch Time: 5.22s, Total Time: 486.09s
# -----------
# Total variation regularization took 1.7434 seconds.
# Epoch 84, Loss: 11.398170, Freq: 100MHz, Epoch Time: 7.93s, Total Time: 494.02s
# -----------
# Total variation regularization took 1.7427 seconds.
# Epoch 85, Loss: 11.325624, Freq: 100MHz, Epoch Time: 5.18s, Total Time: 499.21s
# -----------
# Total variation regularization took 1.7644 seconds.
# Epoch 86, Loss: 10.915100, Freq: 100MHz, Epoch Time: 8.00s, Total Time: 507.21s
# -----------
# Total variation regularization took 1.7252 seconds.
# Epoch 87, Loss: 10.939364, Freq: 100MHz, Epoch Time: 5.16s, Total Time: 512.37s
# -----------
# Total variation regularization took 1.7496 seconds.
# Epoch 88, Loss: 10.703828, Freq: 100MHz, Epoch Time: 7.92s, Total Time: 520.30s
# -----------
# Total variation regularization took 1.7380 seconds.
# Epoch 89, Loss: 10.690207, Freq: 100MHz, Epoch Time: 5.26s, Total Time: 525.56s
# -----------
# Total variation regularization took 1.7485 seconds.
# Epoch 90, Loss: 10.647810, Freq: 100MHz, Epoch Time: 7.88s, Total Time: 533.44s
# -----------
# Total variation regularization took 1.7183 seconds.
# Epoch 91, Loss: 10.505874, Freq: 100MHz, Epoch Time: 5.18s, Total Time: 538.62s
# -----------
# Total variation regularization took 1.7317 seconds.
# Epoch 92, Loss: 10.477033, Freq: 100MHz, Epoch Time: 7.87s, Total Time: 546.49s
# -----------
# Total variation regularization took 1.7212 seconds.
# Epoch 93, Loss: 10.285471, Freq: 100MHz, Epoch Time: 5.17s, Total Time: 551.66s
# -----------
# Total variation regularization took 1.7393 seconds.
# Epoch 94, Loss: 10.306388, Freq: 100MHz, Epoch Time: 7.91s, Total Time: 559.57s
# -----------
# Total variation regularization took 1.8234 seconds.
# Epoch 95, Loss: 10.206059, Freq: 100MHz, Epoch Time: 5.30s, Total Time: 564.87s
# -----------
# Total variation regularization took 1.7110 seconds.
# Epoch 96, Loss: 10.163033, Freq: 100MHz, Epoch Time: 7.89s, Total Time: 572.76s
# -----------
# Total variation regularization took 1.7127 seconds.
# Epoch 97, Loss: 10.076620, Freq: 100MHz, Epoch Time: 5.26s, Total Time: 578.02s
# -----------
# Total variation regularization took 1.7345 seconds.
# Epoch 98, Loss: 9.944538, Freq: 100MHz, Epoch Time: 7.91s, Total Time: 585.93s
# -----------
# Total variation regularization took 1.7713 seconds.
# Epoch 99, Loss: 9.931270, Freq: 100MHz, Epoch Time: 5.20s, Total Time: 591.13s
# -----------

# %%
n=3

# 加载数据
erdir = 'pred_erdp_subw'
epg = np.load(erdir + '/epg.npy')
epsilon_pred = np.load(erdir + '/' + str(n) + 'epsilon.npy')

se_true = np.load(erdir + '/se_true.npy') * 1000
sig = np.load(erdir + '/sig.npy') * 1000
sigma_pred = np.load(erdir + '/' + str(n) + 'sigma.npy')* 1000

fig, axes = plt.subplots(2, 3, figsize=(6, 7))

# For ep_true we can use the numpy array directly since we did not save it in the block above
# Let's rebuild it briefly for plotting, or just plot what we had
ep_true_plot = ep_true

# 第一行
epsilon_images = [ep_true_plot, epg, epsilon_pred]
for i in range(3):
    im1 = axes[0, i].imshow(epsilon_images[i], cmap='jet', aspect='auto', vmin=1, vmax=7)
    axes[0, i].set_title(['epsilon_true', 'epsilon_init', 'epsilon_pred'][i])

# 第二行
sigma_images = [se_true, sig, sigma_pred]
for i in range(3):
    im2 = axes[1, i].imshow(sigma_images[i], cmap='jet', aspect='auto', vmin=0, vmax=1)
    axes[1, i].set_title(['sigma_true', 'sigma_init', 'sigma_pred'][i])

# 第一行colorbar（右上角）
cbar_ax1 = fig.add_axes([0.92, 0.55, 0.02, 0.35])  # [left, bottom, width, height]
cbar1 = fig.colorbar(im1, cax=cbar_ax1)
cbar1.set_label('Epsilon')

# 第二行colorbar（右下角）
cbar_ax2 = fig.add_axes([0.92, 0.1, 0.02, 0.35])
cbar2 = fig.colorbar(im2, cax=cbar_ax2)
cbar2.set_label('Sigma (mS/m)')

plt.subplots_adjust(right=0.9, wspace=0.3, hspace=0.3)
plt.show()
