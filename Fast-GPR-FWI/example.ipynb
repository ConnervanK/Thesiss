# %%
import os
import time
import torch
from src.compute import compute
from src.multiscale import apply_filter
import src.visualization as visualization
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage import filters
import matplotlib.pyplot as plt

device = torch.device('cuda')

ep_true=np.load("newmodel.npy")
ep_true = resize(ep_true, (200, 100), order=1, mode='edge', anti_aliasing=True, preserve_range=True)
padded_ep = np.zeros((220, 120))
padded_ep[10:-10, 10:-10] = ep_true
padded_ep[:10, 10:-10] = ep_true[0:1, :].repeat(10, axis=0)
padded_ep[-10:, 10:-10] = ep_true[-1:, :].repeat(10, axis=0)
padded_ep[:, :10] = padded_ep[:, 10:11].repeat(10, axis=1)
padded_ep[:, -10:] = padded_ep[:, -11:-10].repeat(10, axis=1)
ep_t=torch.tensor(padded_ep,device=device).unsqueeze(-1)
ep_truef=np.fliplr(ep_true) 
ep_truef[:100,:]=ep_true[:100,:]
se_true=ep_truef  *0.001
se_true = resize(se_true, (200, 100), order=1, mode='edge', anti_aliasing=True, preserve_range=True)
se_true[(0.0008 <= se_true) & (se_true <= 0.0011)] = 0

padded_s = np.zeros((220, 120))
padded_s[10:-10, 10:-10] = se_true
padded_s[:10, 10:-10] = se_true[0:1, :].repeat(10, axis=0)
padded_s[-10:, 10:-10] = se_true[-1:, :].repeat(10, axis=0)
padded_s[:, :10] = padded_s[:, 10:11].repeat(10, axis=1)
padded_s[:, -10:] = padded_s[:, -11:-10].repeat(10, axis=1)
se_t = torch.tensor(padded_s, device=device).unsqueeze(-1)
mr_t = torch.ones_like(ep_t)
sm_t = torch.zeros_like(ep_t)
epj=ep_true.copy()
epj[epj <= 2.1] = 5
sej=se_true.copy()
sej[sej <= 0.0021] = 0.005
epg=torch.tensor(filters.gaussian(epj,sigma=20),device=device)#[4:-4,4:-4]
sig=torch.tensor(filters.gaussian(sej,sigma=20),device=device)
ep_init=ep_t.clone()
ep_init[10:-10, 10:-10,0]=epg
se_init=se_t.clone()
se_init[10:-10, 10:-10,0]=sig


erdir = 'pred_erdp'
if not os.path.exists(erdir):
    os.makedirs(erdir)

np.save(erdir+'/epg.npy',epg.cpu())
np.save(erdir+'/sig.npy',sig.cpu())
np.save(erdir+'/se_true.npy',se_true)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))  
im1 = axes[0].imshow(ep_t[:, :, 0].cpu().numpy(),
                     cmap='viridis',
                     interpolation='nearest',
                     aspect='equal')
cbar1 = plt.colorbar(im1, ax=axes[0])
axes[0].set_title('Relative permittivity')
axes[0].set_xlabel('Distance (m)')
axes[0].set_ylabel('Depth (m)')

# 图2: se_t
im2 = axes[1].imshow(se_t[:, :, 0].cpu().numpy(),
                     cmap='viridis',
                     interpolation='nearest',
                     aspect='equal')
cbar2 = plt.colorbar(im2, ax=axes[1])
cbar2.set_label('S/m')
axes[1].set_title('Conductivity')
axes[1].set_xlabel('Distance (m)')
axes[1].set_ylabel('Depth (m)')

plt.tight_layout()
plt.show()


dx = torch.tensor(0.05)
nx= torch.tensor(220)
ny= torch.tensor(120)
nz= torch.tensor(1)
dt=1e-10
time_windows = torch.tensor(1e-7)
source = ['hertzian', 'z']

nsrc = 1
nrx = 200
source_step = torch.tensor([0.25, 0, 0])
receiver_step = torch.tensor([0.05, 0, 0])
source_location = torch.tensor([0.5, 0.50, 0])
receiver_location = torch.tensor([0.5, 5.50, 0]) 

step = 40
source_amplitudes = ['ricker', 1, 1e8]
n_epochs = 202

Target_freq=[1e8]

pmlthick=10
observed_data, tt = compute(device, dx, ny, nx, nz, source, source_amplitudes, step, ep_t,
                           se_t, mr_t, nsrc, nrx, time_windows=time_windows,dt=dt,
                           source_location=source_location, source_step=source_step,
                           receiver_location=receiver_location, receiver_step=receiver_step,
                           pmlthick=pmlthick, Fixedreceiver=True
                            )

pdata=observed_data[20,:,:].cpu().numpy()
# Out:
# c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\torch\cuda\__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GeForce RTX 5060 which is of cuda capability 12.0.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.5) - (10.0)
#
#   warnings.warn(
# c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\torch\cuda\__init__.py:304: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.8 12.9 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   warnings.warn(matched_cuda_warn.format(matched_arches))
# c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\torch\cuda\__init__.py:326: UserWarning:
# NVIDIA GeForce RTX 5060 with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_75 sm_80 sm_86 sm_89 sm_90 sm_100 compute_100.
# If you want to use the NVIDIA GeForce RTX 5060 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(

# %%
er=ep_init.clone()
se=se_init.clone()

mr = mr_t.clone()

optimiser_phase1 = torch.optim.Adam([
    {'params': er, 'lr': 0.2},
])

optimiser_phase2 = torch.optim.Adam([
    {'params': er, 'lr': 0.1},
    {'params': se, 'lr': 0.0001}
])
phase1_epochs = 50 
losses = []
Change_freq=1000



loss_fnmse = torch.nn.MSELoss()
loss_fnl1= torch.nn.L1Loss()

start_time = time.time()

for epoch in range(n_epochs):
    if epoch < phase1_epochs:
        current_optimizer = optimiser_phase1
        se.requires_grad = False 
        er.requires_grad = True  
    else:
        current_optimizer = optimiser_phase2
        se.requires_grad = True    
        er.requires_grad = True   
    
    epoch_start = time.time()
    if 'Target_freq' in globals():
        n = epoch // Change_freq
        if n >= len(Target_freq) or len(Target_freq)==1:
            freq = source_amplitudes[2]
            observed_data1=observed_data
        else:
            freq = Target_freq[n]
            observed_data1= apply_filter(observed_data.detach(),1/dt,freq)

    
    current_optimizer.zero_grad()

    result, tt = compute(device, dx, ny, nx, nz, source, source_amplitudes, step, er,
                           se, mr, nsrc, nrx, time_windows=time_windows,dt=dt,
                           source_location=source_location, source_step=source_step,
                           receiver_location=receiver_location, receiver_step=receiver_step,
                           pmlthick=pmlthick, Fixedreceiver=True,freq=freq
                            )
  
    loss = loss_fnl1(result, observed_data) * 100

    loss.backward()
    if er.requires_grad:
        er.grad[:, :pmlthick, :] = 0
        er.grad[:, -pmlthick:, :] = 0
    if se.requires_grad:
        se.grad[:, :pmlthick, :] = 0
        se.grad[:, -pmlthick:, :] = 0
    current_optimizer.step()
    losses.append(loss.item())  # 记录loss值
    epoch_time = time.time() - epoch_start  # 计算当前 epoch 用时
    total_time = time.time() - start_time  # 计算总用时
    ssim_value = visualization.calculatessim(er[pmlthick:-pmlthick, pmlthick:-pmlthick, :], ep_t[pmlthick:-pmlthick, pmlthick:-pmlthick, :])
    print(f"Epoch {epoch}, Loss: {loss.item():.6f}, Freq: {freq/1000000:.0f}MHz, Epoch Time: {epoch_time:.2f}s, Total Time: {total_time:.2f}s")
    save_epoch=10
    if epoch % save_epoch == 0:
        er_ = er[pmlthick:-pmlthick, pmlthick:-pmlthick, :]
        se_ = se[pmlthick:-pmlthick, pmlthick:-pmlthick, :]
        np.save(erdir + "/" + str(int(epoch / save_epoch)) + "sigma.npy", se_.cpu().detach().numpy())
        np.save(erdir + "/" + str(int(epoch /save_epoch)) + "epsilon.npy", er_.cpu().detach().numpy())
    
    with torch.no_grad():
        se.data.clamp_(min=0.000, max=0.006)
        er.data.clamp_(min=1)

    print("-----------")
# Out:
# Total variation regularization took 1.4549 seconds.
# Epoch 0, Loss: 14.195280, Freq: 100MHz, Epoch Time: 5.44s, Total Time: 5.44s
# -----------
# Total variation regularization took 0.8792 seconds.
# Epoch 1, Loss: 11.209087, Freq: 100MHz, Epoch Time: 5.96s, Total Time: 11.60s
# -----------
# Total variation regularization took 0.8595 seconds.
# Epoch 2, Loss: 9.236920, Freq: 100MHz, Epoch Time: 4.18s, Total Time: 15.78s
# -----------
# Total variation regularization took 0.8731 seconds.
# Epoch 3, Loss: 8.203907, Freq: 100MHz, Epoch Time: 5.44s, Total Time: 21.22s
# -----------
# Total variation regularization took 0.8978 seconds.
# Epoch 4, Loss: 7.494887, Freq: 100MHz, Epoch Time: 4.33s, Total Time: 25.56s
# -----------
# Total variation regularization took 0.8745 seconds.
# Epoch 5, Loss: 6.623819, Freq: 100MHz, Epoch Time: 8.15s, Total Time: 33.70s
# -----------
# Total variation regularization took 0.8561 seconds.
# Epoch 6, Loss: 5.828032, Freq: 100MHz, Epoch Time: 37.62s, Total Time: 71.32s
# -----------
# Total variation regularization took 0.8560 seconds.
# Epoch 7, Loss: 5.385729, Freq: 100MHz, Epoch Time: 33.01s, Total Time: 104.33s
# -----------
# Total variation regularization took 0.8534 seconds.
# Epoch 8, Loss: 4.902347, Freq: 100MHz, Epoch Time: 41.01s, Total Time: 145.34s
# -----------
# Total variation regularization took 0.8528 seconds.
# Epoch 9, Loss: 4.434242, Freq: 100MHz, Epoch Time: 25.38s, Total Time: 170.72s
# -----------
# Total variation regularization took 0.8608 seconds.
# Epoch 10, Loss: 4.302723, Freq: 100MHz, Epoch Time: 16.05s, Total Time: 186.78s
# -----------
# Total variation regularization took 0.8801 seconds.
# Epoch 11, Loss: 4.366878, Freq: 100MHz, Epoch Time: 25.58s, Total Time: 212.36s
# -----------
# Total variation regularization took 0.8996 seconds.
# Epoch 12, Loss: 4.297459, Freq: 100MHz, Epoch Time: 16.23s, Total Time: 228.58s
# -----------
# Total variation regularization took 0.8567 seconds.
# Epoch 13, Loss: 4.085509, Freq: 100MHz, Epoch Time: 25.63s, Total Time: 254.22s
# -----------
# Total variation regularization took 0.8475 seconds.
# Epoch 14, Loss: 3.811078, Freq: 100MHz, Epoch Time: 16.03s, Total Time: 270.25s
# -----------
# Total variation regularization took 0.8669 seconds.
# Epoch 15, Loss: 3.539745, Freq: 100MHz, Epoch Time: 25.52s, Total Time: 295.77s
# -----------
# Total variation regularization took 0.9059 seconds.
# Epoch 16, Loss: 3.364702, Freq: 100MHz, Epoch Time: 17.13s, Total Time: 312.91s
# -----------
# Total variation regularization took 0.8548 seconds.
# Epoch 17, Loss: 3.293173, Freq: 100MHz, Epoch Time: 25.85s, Total Time: 338.76s
# -----------
# Total variation regularization took 0.9280 seconds.
# Epoch 18, Loss: 3.295174, Freq: 100MHz, Epoch Time: 16.29s, Total Time: 355.04s
# -----------
# Total variation regularization took 0.8657 seconds.
# Epoch 19, Loss: 3.289905, Freq: 100MHz, Epoch Time: 27.34s, Total Time: 382.39s
# -----------
# Total variation regularization took 1.0778 seconds.
# Epoch 20, Loss: 3.240834, Freq: 100MHz, Epoch Time: 17.92s, Total Time: 400.31s
# -----------
# Total variation regularization took 0.8815 seconds.
# Epoch 21, Loss: 3.174135, Freq: 100MHz, Epoch Time: 27.90s, Total Time: 428.21s
# -----------
# Total variation regularization took 0.8690 seconds.
# Epoch 22, Loss: 3.095155, Freq: 100MHz, Epoch Time: 17.30s, Total Time: 445.52s
# -----------
# Total variation regularization took 0.8835 seconds.
# Epoch 23, Loss: 3.056044, Freq: 100MHz, Epoch Time: 25.87s, Total Time: 471.39s
# -----------
# Total variation regularization took 0.8966 seconds.
# Epoch 24, Loss: 3.058518, Freq: 100MHz, Epoch Time: 16.65s, Total Time: 488.05s
# -----------
# Total variation regularization took 0.8469 seconds.
# Epoch 25, Loss: 3.073637, Freq: 100MHz, Epoch Time: 25.27s, Total Time: 513.32s
# -----------
# Total variation regularization took 0.8450 seconds.
# Epoch 26, Loss: 3.029769, Freq: 100MHz, Epoch Time: 15.82s, Total Time: 529.14s
# -----------
# Total variation regularization took 0.8544 seconds.
# Epoch 27, Loss: 2.954254, Freq: 100MHz, Epoch Time: 25.21s, Total Time: 554.36s
# -----------
# Total variation regularization took 0.8481 seconds.
# Epoch 28, Loss: 2.900131, Freq: 100MHz, Epoch Time: 15.88s, Total Time: 570.24s
# -----------
# Total variation regularization took 0.8478 seconds.
# Epoch 29, Loss: 2.894043, Freq: 100MHz, Epoch Time: 16.50s, Total Time: 586.74s
# -----------
# Total variation regularization took 0.8561 seconds.
# Epoch 30, Loss: 2.928837, Freq: 100MHz, Epoch Time: 4.57s, Total Time: 591.31s
# -----------
# Total variation regularization took 0.8518 seconds.
# Epoch 31, Loss: 2.910499, Freq: 100MHz, Epoch Time: 5.40s, Total Time: 596.71s
# -----------
# Total variation regularization took 0.8512 seconds.
# Epoch 32, Loss: 2.873031, Freq: 100MHz, Epoch Time: 4.13s, Total Time: 600.84s
# -----------
# Total variation regularization took 0.8514 seconds.
# Epoch 33, Loss: 2.835588, Freq: 100MHz, Epoch Time: 5.41s, Total Time: 606.25s
# -----------
# Total variation regularization took 0.8490 seconds.
# Epoch 34, Loss: 2.815727, Freq: 100MHz, Epoch Time: 4.13s, Total Time: 610.39s
# -----------
# Total variation regularization took 0.8545 seconds.
# Epoch 35, Loss: 2.846212, Freq: 100MHz, Epoch Time: 5.40s, Total Time: 615.79s
# -----------
# Total variation regularization took 0.8558 seconds.
# Epoch 36, Loss: 2.843282, Freq: 100MHz, Epoch Time: 4.13s, Total Time: 619.92s
# -----------
# Total variation regularization took 0.8490 seconds.
# Epoch 37, Loss: 2.838687, Freq: 100MHz, Epoch Time: 5.40s, Total Time: 625.32s
# -----------
# Total variation regularization took 0.8575 seconds.
# Epoch 38, Loss: 2.811413, Freq: 100MHz, Epoch Time: 4.13s, Total Time: 629.46s
# -----------
# Total variation regularization took 0.8544 seconds.
# Epoch 39, Loss: 2.810461, Freq: 100MHz, Epoch Time: 5.40s, Total Time: 634.86s
# -----------
# Total variation regularization took 0.8530 seconds.
# Epoch 40, Loss: 2.797184, Freq: 100MHz, Epoch Time: 4.13s, Total Time: 638.99s
# -----------
# Total variation regularization took 0.8513 seconds.
# Epoch 41, Loss: 2.783074, Freq: 100MHz, Epoch Time: 5.41s, Total Time: 644.40s
# -----------
# Total variation regularization took 0.8531 seconds.
# Epoch 42, Loss: 2.778627, Freq: 100MHz, Epoch Time: 4.13s, Total Time: 648.54s
# -----------
# Total variation regularization took 1.0604 seconds.
# Epoch 43, Loss: 2.760884, Freq: 100MHz, Epoch Time: 5.62s, Total Time: 654.15s
# -----------
# Total variation regularization took 1.1020 seconds.
# Epoch 44, Loss: 2.732820, Freq: 100MHz, Epoch Time: 4.88s, Total Time: 659.04s
# -----------
# Total variation regularization took 1.0695 seconds.
# Epoch 45, Loss: 2.730651, Freq: 100MHz, Epoch Time: 5.62s, Total Time: 664.66s
# -----------
# Total variation regularization took 0.8514 seconds.
# Epoch 46, Loss: 2.763328, Freq: 100MHz, Epoch Time: 4.29s, Total Time: 668.95s
# -----------
# Total variation regularization took 0.8410 seconds.
# Epoch 47, Loss: 2.759027, Freq: 100MHz, Epoch Time: 5.80s, Total Time: 674.75s
# -----------
# Total variation regularization took 0.8434 seconds.
# Epoch 48, Loss: 2.741845, Freq: 100MHz, Epoch Time: 4.10s, Total Time: 678.86s
# -----------
# Total variation regularization took 0.8427 seconds.
# Epoch 49, Loss: 2.732527, Freq: 100MHz, Epoch Time: 5.40s, Total Time: 684.26s
# -----------
# Total variation regularization took 1.6877 seconds.
# Epoch 50, Loss: 2.718535, Freq: 100MHz, Epoch Time: 5.04s, Total Time: 689.31s
# -----------
# Total variation regularization took 1.6974 seconds.
# Epoch 51, Loss: 4.037628, Freq: 100MHz, Epoch Time: 6.62s, Total Time: 695.93s
# -----------
# Total variation regularization took 1.6985 seconds.
# Epoch 52, Loss: 3.346019, Freq: 100MHz, Epoch Time: 5.09s, Total Time: 701.02s
# -----------
# Total variation regularization took 1.7003 seconds.
# Epoch 53, Loss: 2.788224, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 707.67s
# -----------
# Total variation regularization took 1.7039 seconds.
# Epoch 54, Loss: 2.528224, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 712.77s
# -----------
# Total variation regularization took 1.7041 seconds.
# Epoch 55, Loss: 2.205749, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 719.42s
# -----------
# Total variation regularization took 1.6964 seconds.
# Epoch 56, Loss: 1.907389, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 724.54s
# -----------
# Total variation regularization took 1.7801 seconds.
# Epoch 57, Loss: 1.867785, Freq: 100MHz, Epoch Time: 6.72s, Total Time: 731.26s
# -----------
# Total variation regularization took 2.1474 seconds.
# Epoch 58, Loss: 1.830471, Freq: 100MHz, Epoch Time: 6.05s, Total Time: 737.32s
# -----------
# Total variation regularization took 1.8493 seconds.
# Epoch 59, Loss: 1.661967, Freq: 100MHz, Epoch Time: 7.74s, Total Time: 745.06s
# -----------
# Total variation regularization took 1.7241 seconds.
# Epoch 60, Loss: 1.444903, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 750.21s
# -----------
# Total variation regularization took 1.7291 seconds.
# Epoch 61, Loss: 1.411513, Freq: 100MHz, Epoch Time: 6.69s, Total Time: 756.90s
# -----------
# Total variation regularization took 1.8272 seconds.
# Epoch 62, Loss: 1.337279, Freq: 100MHz, Epoch Time: 5.24s, Total Time: 762.14s
# -----------
# Total variation regularization took 1.7439 seconds.
# Epoch 63, Loss: 1.198414, Freq: 100MHz, Epoch Time: 7.11s, Total Time: 769.25s
# -----------
# Total variation regularization took 2.6856 seconds.
# Epoch 64, Loss: 1.115324, Freq: 100MHz, Epoch Time: 6.79s, Total Time: 776.04s
# -----------
# Total variation regularization took 2.1471 seconds.
# Epoch 65, Loss: 1.045874, Freq: 100MHz, Epoch Time: 8.04s, Total Time: 784.08s
# -----------
# Total variation regularization took 2.4548 seconds.
# Epoch 66, Loss: 1.006123, Freq: 100MHz, Epoch Time: 7.06s, Total Time: 791.14s
# -----------
# Total variation regularization took 1.9454 seconds.
# Epoch 67, Loss: 0.913483, Freq: 100MHz, Epoch Time: 7.47s, Total Time: 798.62s
# -----------
# Total variation regularization took 1.7663 seconds.
# Epoch 68, Loss: 0.833581, Freq: 100MHz, Epoch Time: 5.71s, Total Time: 804.33s
# -----------
# Total variation regularization took 1.7528 seconds.
# Epoch 69, Loss: 0.814050, Freq: 100MHz, Epoch Time: 6.78s, Total Time: 811.12s
# -----------
# Total variation regularization took 1.7621 seconds.
# Epoch 70, Loss: 0.743287, Freq: 100MHz, Epoch Time: 5.24s, Total Time: 816.36s
# -----------
# Total variation regularization took 1.7620 seconds.
# Epoch 71, Loss: 0.698268, Freq: 100MHz, Epoch Time: 6.92s, Total Time: 823.28s
# -----------
# Total variation regularization took 1.7551 seconds.
# Epoch 72, Loss: 0.659837, Freq: 100MHz, Epoch Time: 5.22s, Total Time: 828.50s
# -----------
# Total variation regularization took 1.7582 seconds.
# Epoch 73, Loss: 0.646068, Freq: 100MHz, Epoch Time: 6.81s, Total Time: 835.32s
# -----------
# Total variation regularization took 1.7545 seconds.
# Epoch 74, Loss: 0.587908, Freq: 100MHz, Epoch Time: 5.24s, Total Time: 840.55s
# -----------
# Total variation regularization took 1.7663 seconds.
# Epoch 75, Loss: 0.598155, Freq: 100MHz, Epoch Time: 6.79s, Total Time: 847.34s
# -----------
# Total variation regularization took 1.7790 seconds.
# Epoch 76, Loss: 0.571857, Freq: 100MHz, Epoch Time: 5.23s, Total Time: 852.58s
# -----------
# Total variation regularization took 1.7469 seconds.
# Epoch 77, Loss: 0.547916, Freq: 100MHz, Epoch Time: 6.97s, Total Time: 859.55s
# -----------
# Total variation regularization took 1.7228 seconds.
# Epoch 78, Loss: 0.570601, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 864.66s
# -----------
# Total variation regularization took 1.7338 seconds.
# Epoch 79, Loss: 0.568474, Freq: 100MHz, Epoch Time: 6.72s, Total Time: 871.38s
# -----------
# Total variation regularization took 1.7247 seconds.
# Epoch 80, Loss: 0.516779, Freq: 100MHz, Epoch Time: 5.18s, Total Time: 876.57s
# -----------
# Total variation regularization took 1.7145 seconds.
# Epoch 81, Loss: 0.493558, Freq: 100MHz, Epoch Time: 7.00s, Total Time: 883.57s
# -----------
# Total variation regularization took 1.7058 seconds.
# Epoch 82, Loss: 0.469456, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 888.69s
# -----------
# Total variation regularization took 1.7082 seconds.
# Epoch 83, Loss: 0.502400, Freq: 100MHz, Epoch Time: 6.66s, Total Time: 895.35s
# -----------
# Total variation regularization took 1.7041 seconds.
# Epoch 84, Loss: 0.481110, Freq: 100MHz, Epoch Time: 5.09s, Total Time: 900.44s
# -----------
# Total variation regularization took 1.6994 seconds.
# Epoch 85, Loss: 0.435560, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 907.09s
# -----------
# Total variation regularization took 1.7069 seconds.
# Epoch 86, Loss: 0.442532, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 912.20s
# -----------
# Total variation regularization took 1.6944 seconds.
# Epoch 87, Loss: 0.424003, Freq: 100MHz, Epoch Time: 6.66s, Total Time: 918.86s
# -----------
# Total variation regularization took 1.6950 seconds.
# Epoch 88, Loss: 0.397136, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 923.97s
# -----------
# Total variation regularization took 1.6876 seconds.
# Epoch 89, Loss: 0.419013, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 930.61s
# -----------
# Total variation regularization took 1.7018 seconds.
# Epoch 90, Loss: 0.427759, Freq: 100MHz, Epoch Time: 5.13s, Total Time: 935.74s
# -----------
# Total variation regularization took 1.7004 seconds.
# Epoch 91, Loss: 0.390863, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 942.39s
# -----------
# Total variation regularization took 1.6992 seconds.
# Epoch 92, Loss: 0.412660, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 947.51s
# -----------
# Total variation regularization took 1.7014 seconds.
# Epoch 93, Loss: 0.450005, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 954.16s
# -----------
# Total variation regularization took 1.7012 seconds.
# Epoch 94, Loss: 0.372469, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 959.28s
# -----------
# Total variation regularization took 1.6895 seconds.
# Epoch 95, Loss: 0.461826, Freq: 100MHz, Epoch Time: 6.63s, Total Time: 965.92s
# -----------
# Total variation regularization took 1.6977 seconds.
# Epoch 96, Loss: 0.385153, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 971.04s
# -----------
# Total variation regularization took 1.6964 seconds.
# Epoch 97, Loss: 0.549747, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 977.69s
# -----------
# Total variation regularization took 1.6991 seconds.
# Epoch 98, Loss: 0.578956, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 982.80s
# -----------
# Total variation regularization took 1.6983 seconds.
# Epoch 99, Loss: 0.410577, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 989.45s
# -----------
# Total variation regularization took 1.6969 seconds.
# Epoch 100, Loss: 0.501751, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 994.56s
# -----------
# Total variation regularization took 1.7040 seconds.
# Epoch 101, Loss: 0.443977, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1001.22s
# -----------
# Total variation regularization took 1.6980 seconds.
# Epoch 102, Loss: 0.475444, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1006.33s
# -----------
# Total variation regularization took 1.6939 seconds.
# Epoch 103, Loss: 0.510262, Freq: 100MHz, Epoch Time: 6.63s, Total Time: 1012.97s
# -----------
# Total variation regularization took 1.6933 seconds.
# Epoch 104, Loss: 0.479072, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1018.09s
# -----------
# Total variation regularization took 1.6957 seconds.
# Epoch 105, Loss: 0.427801, Freq: 100MHz, Epoch Time: 6.63s, Total Time: 1024.73s
# -----------
# Total variation regularization took 1.6927 seconds.
# Epoch 106, Loss: 0.534302, Freq: 100MHz, Epoch Time: 5.08s, Total Time: 1029.81s
# -----------
# Total variation regularization took 1.7011 seconds.
# Epoch 107, Loss: 0.440400, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1036.45s
# -----------
# Total variation regularization took 1.7019 seconds.
# Epoch 108, Loss: 0.474104, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 1041.56s
# -----------
# Total variation regularization took 1.7004 seconds.
# Epoch 109, Loss: 0.505834, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1048.20s
# -----------
# Total variation regularization took 1.6954 seconds.
# Epoch 110, Loss: 0.382255, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1053.31s
# -----------
# Total variation regularization took 1.7008 seconds.
# Epoch 111, Loss: 0.418377, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1059.96s
# -----------
# Total variation regularization took 1.6983 seconds.
# Epoch 112, Loss: 0.436110, Freq: 100MHz, Epoch Time: 5.13s, Total Time: 1065.09s
# -----------
# Total variation regularization took 1.7026 seconds.
# Epoch 113, Loss: 0.373025, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1071.74s
# -----------
# Total variation regularization took 1.6996 seconds.
# Epoch 114, Loss: 0.482451, Freq: 100MHz, Epoch Time: 5.09s, Total Time: 1076.84s
# -----------
# Total variation regularization took 1.7151 seconds.
# Epoch 115, Loss: 0.465535, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1083.49s
# -----------
# Total variation regularization took 1.7026 seconds.
# Epoch 116, Loss: 0.399499, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 1088.59s
# -----------
# Total variation regularization took 1.6982 seconds.
# Epoch 117, Loss: 0.376375, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1095.23s
# -----------
# Total variation regularization took 1.7097 seconds.
# Epoch 118, Loss: 0.422384, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1100.35s
# -----------
# Total variation regularization took 1.7000 seconds.
# Epoch 119, Loss: 0.386413, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1107.00s
# -----------
# Total variation regularization took 1.6972 seconds.
# Epoch 120, Loss: 0.437879, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1112.12s
# -----------
# Total variation regularization took 1.7350 seconds.
# Epoch 121, Loss: 0.446401, Freq: 100MHz, Epoch Time: 6.68s, Total Time: 1118.80s
# -----------
# Total variation regularization took 1.6919 seconds.
# Epoch 122, Loss: 0.385391, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1123.91s
# -----------
# Total variation regularization took 1.6989 seconds.
# Epoch 123, Loss: 0.332213, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1130.55s
# -----------
# Total variation regularization took 1.7002 seconds.
# Epoch 124, Loss: 0.417868, Freq: 100MHz, Epoch Time: 5.09s, Total Time: 1135.64s
# -----------
# Total variation regularization took 1.7020 seconds.
# Epoch 125, Loss: 0.333279, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1142.29s
# -----------
# Total variation regularization took 1.7012 seconds.
# Epoch 126, Loss: 0.480347, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1147.40s
# -----------
# Total variation regularization took 1.6995 seconds.
# Epoch 127, Loss: 0.498931, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1154.05s
# -----------
# Total variation regularization took 1.6965 seconds.
# Epoch 128, Loss: 0.322831, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 1159.15s
# -----------
# Total variation regularization took 1.7016 seconds.
# Epoch 129, Loss: 0.408849, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1165.80s
# -----------
# Total variation regularization took 1.7040 seconds.
# Epoch 130, Loss: 0.412017, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1170.91s
# -----------
# Total variation regularization took 1.6959 seconds.
# Epoch 131, Loss: 0.348157, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1177.57s
# -----------
# Total variation regularization took 1.7064 seconds.
# Epoch 132, Loss: 0.391454, Freq: 100MHz, Epoch Time: 5.13s, Total Time: 1182.70s
# -----------
# Total variation regularization took 1.7042 seconds.
# Epoch 133, Loss: 0.337438, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1189.36s
# -----------
# Total variation regularization took 1.7030 seconds.
# Epoch 134, Loss: 0.413894, Freq: 100MHz, Epoch Time: 5.09s, Total Time: 1194.44s
# -----------
# Total variation regularization took 1.7010 seconds.
# Epoch 135, Loss: 0.426349, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1201.09s
# -----------
# Total variation regularization took 1.7020 seconds.
# Epoch 136, Loss: 0.334094, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 1206.19s
# -----------
# Total variation regularization took 1.6969 seconds.
# Epoch 137, Loss: 0.346415, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1212.84s
# -----------
# Total variation regularization took 1.6992 seconds.
# Epoch 138, Loss: 0.352426, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1217.94s
# -----------
# Total variation regularization took 1.7029 seconds.
# Epoch 139, Loss: 0.306898, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1224.59s
# -----------
# Total variation regularization took 1.7031 seconds.
# Epoch 140, Loss: 0.411130, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1229.72s
# -----------
# Total variation regularization took 1.7028 seconds.
# Epoch 141, Loss: 0.386528, Freq: 100MHz, Epoch Time: 6.67s, Total Time: 1236.41s
# -----------
# Total variation regularization took 1.7003 seconds.
# Epoch 142, Loss: 0.393951, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1241.52s
# -----------
# Total variation regularization took 1.6950 seconds.
# Epoch 143, Loss: 0.346497, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1248.16s
# -----------
# Total variation regularization took 1.7000 seconds.
# Epoch 144, Loss: 0.391579, Freq: 100MHz, Epoch Time: 5.13s, Total Time: 1253.30s
# -----------
# Total variation regularization took 1.7016 seconds.
# Epoch 145, Loss: 0.336959, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1259.95s
# -----------
# Total variation regularization took 1.6984 seconds.
# Epoch 146, Loss: 0.437738, Freq: 100MHz, Epoch Time: 5.09s, Total Time: 1265.04s
# -----------
# Total variation regularization took 1.7032 seconds.
# Epoch 147, Loss: 0.439212, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1271.69s
# -----------
# Total variation regularization took 1.7019 seconds.
# Epoch 148, Loss: 0.349902, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1276.81s
# -----------
# Total variation regularization took 1.6973 seconds.
# Epoch 149, Loss: 0.317471, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1283.45s
# -----------
# Total variation regularization took 1.6995 seconds.
# Epoch 150, Loss: 0.406758, Freq: 100MHz, Epoch Time: 5.11s, Total Time: 1288.56s
# -----------
# Total variation regularization took 1.7021 seconds.
# Epoch 151, Loss: 0.363391, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1295.21s
# -----------
# Total variation regularization took 1.6972 seconds.
# Epoch 152, Loss: 0.420662, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1300.33s
# -----------
# Total variation regularization took 1.7084 seconds.
# Epoch 153, Loss: 0.400380, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1306.98s
# -----------
# Total variation regularization took 1.6979 seconds.
# Epoch 154, Loss: 0.343989, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1312.11s
# -----------
# Total variation regularization took 1.6954 seconds.
# Epoch 155, Loss: 0.324937, Freq: 100MHz, Epoch Time: 6.64s, Total Time: 1318.75s
# -----------
# Total variation regularization took 1.7048 seconds.
# Epoch 156, Loss: 0.421011, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 1323.85s
# -----------
# Total variation regularization took 1.7038 seconds.
# Epoch 157, Loss: 0.398451, Freq: 100MHz, Epoch Time: 6.66s, Total Time: 1330.51s
# -----------
# Total variation regularization took 1.7006 seconds.
# Epoch 158, Loss: 0.333412, Freq: 100MHz, Epoch Time: 5.14s, Total Time: 1335.65s
# -----------
# Total variation regularization took 1.7003 seconds.
# Epoch 159, Loss: 0.304161, Freq: 100MHz, Epoch Time: 6.66s, Total Time: 1342.31s
# -----------
# Total variation regularization took 1.6984 seconds.
# Epoch 160, Loss: 0.420672, Freq: 100MHz, Epoch Time: 5.10s, Total Time: 1347.41s
# -----------
# Total variation regularization took 1.6986 seconds.
# Epoch 161, Loss: 0.394618, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1354.06s
# -----------
# Total variation regularization took 1.7240 seconds.
# Epoch 162, Loss: 0.369326, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1359.19s
# -----------
# Total variation regularization took 1.6974 seconds.
# Epoch 163, Loss: 0.340811, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1365.84s
# -----------
# Total variation regularization took 1.7052 seconds.
# Epoch 164, Loss: 0.385576, Freq: 100MHz, Epoch Time: 5.12s, Total Time: 1370.96s
# -----------
# Total variation regularization took 1.6994 seconds.
# Epoch 165, Loss: 0.360785, Freq: 100MHz, Epoch Time: 6.65s, Total Time: 1377.61s
# -----------
# Total variation regularization took 1.7766 seconds.
# Epoch 166, Loss: 0.370510, Freq: 100MHz, Epoch Time: 5.22s, Total Time: 1382.83s
# -----------
# Total variation regularization took 1.8265 seconds.
# Epoch 167, Loss: 0.359169, Freq: 100MHz, Epoch Time: 7.05s, Total Time: 1389.88s
# -----------
# Total variation regularization took 1.7011 seconds.
# Epoch 168, Loss: 0.384617, Freq: 100MHz, Epoch Time: 5.15s, Total Time: 1395.02s
# -----------
# Total variation regularization took 2.2246 seconds.
# Epoch 169, Loss: 0.343692, Freq: 100MHz, Epoch Time: 7.41s, Total Time: 1402.44s
# -----------
# Total variation regularization took 2.3399 seconds.
# Epoch 170, Loss: 0.388568, Freq: 100MHz, Epoch Time: 6.25s, Total Time: 1408.69s
# -----------
# Total variation regularization took 1.9424 seconds.
# Epoch 171, Loss: 0.387008, Freq: 100MHz, Epoch Time: 7.70s, Total Time: 1416.40s
# -----------
# Total variation regularization took 3.6195 seconds.
# Epoch 172, Loss: 0.355837, Freq: 100MHz, Epoch Time: 8.98s, Total Time: 1425.38s
# -----------
# Total variation regularization took 2.6731 seconds.
# Epoch 173, Loss: 0.311827, Freq: 100MHz, Epoch Time: 9.63s, Total Time: 1435.01s
# -----------
# Total variation regularization took 1.8742 seconds.
# Epoch 174, Loss: 0.410743, Freq: 100MHz, Epoch Time: 5.51s, Total Time: 1440.52s
# -----------
# Total variation regularization took 2.6546 seconds.
# Epoch 175, Loss: 0.389307, Freq: 100MHz, Epoch Time: 8.22s, Total Time: 1448.75s
# -----------
# Total variation regularization took 2.3177 seconds.
# Epoch 176, Loss: 0.350430, Freq: 100MHz, Epoch Time: 6.73s, Total Time: 1455.48s
# -----------
# Total variation regularization took 2.9095 seconds.
# Epoch 177, Loss: 0.321202, Freq: 100MHz, Epoch Time: 8.64s, Total Time: 1464.12s
# -----------
# Total variation regularization took 2.1389 seconds.
# Epoch 178, Loss: 0.397614, Freq: 100MHz, Epoch Time: 6.37s, Total Time: 1470.49s
# -----------
# Total variation regularization took 2.3497 seconds.
# Epoch 179, Loss: 0.381308, Freq: 100MHz, Epoch Time: 8.23s, Total Time: 1478.72s
# -----------
# Total variation regularization took 2.6008 seconds.
# Epoch 180, Loss: 0.347670, Freq: 100MHz, Epoch Time: 7.09s, Total Time: 1485.81s
# -----------
# Total variation regularization took 2.0076 seconds.
# Epoch 181, Loss: 0.324266, Freq: 100MHz, Epoch Time: 7.97s, Total Time: 1493.79s
# -----------
# Total variation regularization took 2.0443 seconds.
# Epoch 182, Loss: 0.395680, Freq: 100MHz, Epoch Time: 6.15s, Total Time: 1499.94s
# -----------
# Total variation regularization took 2.7681 seconds.
# Epoch 183, Loss: 0.369884, Freq: 100MHz, Epoch Time: 8.78s, Total Time: 1508.72s
# -----------
# Total variation regularization took 2.2302 seconds.
# Epoch 184, Loss: 0.358277, Freq: 100MHz, Epoch Time: 7.41s, Total Time: 1516.13s
# -----------
# Total variation regularization took 2.4943 seconds.
# Epoch 185, Loss: 0.333401, Freq: 100MHz, Epoch Time: 8.42s, Total Time: 1524.56s
# -----------
# Total variation regularization took 2.7343 seconds.
# Epoch 186, Loss: 0.388898, Freq: 100MHz, Epoch Time: 7.36s, Total Time: 1531.92s
# -----------
# Total variation regularization took 2.8280 seconds.
# Epoch 187, Loss: 0.368730, Freq: 100MHz, Epoch Time: 9.02s, Total Time: 1540.94s
# -----------
# Total variation regularization took 2.2736 seconds.
# Epoch 188, Loss: 0.361465, Freq: 100MHz, Epoch Time: 7.17s, Total Time: 1548.11s
# -----------
# Total variation regularization took 2.6661 seconds.
# Epoch 189, Loss: 0.338646, Freq: 100MHz, Epoch Time: 8.66s, Total Time: 1556.78s
# -----------
# Total variation regularization took 2.8449 seconds.
# Epoch 190, Loss: 0.391342, Freq: 100MHz, Epoch Time: 6.98s, Total Time: 1563.76s
# -----------
# Total variation regularization took 3.1086 seconds.
# Epoch 191, Loss: 0.364546, Freq: 100MHz, Epoch Time: 9.68s, Total Time: 1573.44s
# -----------
# Total variation regularization took 2.2318 seconds.
# Epoch 192, Loss: 0.366384, Freq: 100MHz, Epoch Time: 6.68s, Total Time: 1580.12s
# -----------
# Total variation regularization took 2.4392 seconds.
# Epoch 193, Loss: 0.348011, Freq: 100MHz, Epoch Time: 8.18s, Total Time: 1588.31s
# -----------
# Total variation regularization took 2.4226 seconds.
# Epoch 194, Loss: 0.377922, Freq: 100MHz, Epoch Time: 6.97s, Total Time: 1595.27s
# -----------
# Total variation regularization took 2.7355 seconds.
# Epoch 195, Loss: 0.353346, Freq: 100MHz, Epoch Time: 8.91s, Total Time: 1604.18s
# -----------
# Total variation regularization took 1.9088 seconds.
# Epoch 196, Loss: 0.370791, Freq: 100MHz, Epoch Time: 6.06s, Total Time: 1610.24s
# -----------
# Total variation regularization took 2.7623 seconds.
# Epoch 197, Loss: 0.345654, Freq: 100MHz, Epoch Time: 9.02s, Total Time: 1619.26s
# -----------
# Total variation regularization took 2.2643 seconds.
# Epoch 198, Loss: 0.385104, Freq: 100MHz, Epoch Time: 6.91s, Total Time: 1626.17s
# -----------
# Total variation regularization took 2.2834 seconds.
# Epoch 199, Loss: 0.365740, Freq: 100MHz, Epoch Time: 8.15s, Total Time: 1634.33s
# -----------
# Total variation regularization took 2.6678 seconds.
# Epoch 200, Loss: 0.380205, Freq: 100MHz, Epoch Time: 6.56s, Total Time: 1640.89s
# -----------
# Total variation regularization took 2.7626 seconds.
# Epoch 201, Loss: 0.359061, Freq: 100MHz, Epoch Time: 9.02s, Total Time: 1649.91s
# -----------

# %%
n=15

# 加载数据
ep_true = np.load('newmodel.npy')
ep_true = resize(ep_true, (200, 100), order=1, mode='edge', anti_aliasing=True, preserve_range=True)
epg = np.load('pred_erdp/epg.npy')
epsilon_pred = np.load('pred_erdp/'+str(n)+'epsilon.npy')

se_true = np.load('pred_erdp/se_true.npy')*1000
sig = np.load('pred_erdp/sig.npy')*1000
sigma_pred = np.load('pred_erdp/'+str(n)+'sigma.npy')*1000

fig, axes = plt.subplots(2, 3, figsize=(6, 7))

# 第一行
epsilon_images = [ep_true, epg, epsilon_pred]
for i in range(3):
    im1 = axes[0, i].imshow(epsilon_images[i], cmap='jet', aspect='auto', vmin=1, vmax=7)
    axes[0, i].set_title(['epsilon_true', 'epsilon_init', 'epsilon_pred'][i])

# 第二行
sigma_images = [se_true, sig, sigma_pred]
for i in range(3):
    im2 = axes[1, i].imshow(sigma_images[i], cmap='jet', aspect='auto', vmin=0, vmax=7)
    axes[1, i].set_title(['sigma_true', 'sigma_init', 'sigma_pred'][i])

# 第一行colorbar（右上角）
cbar_ax1 = fig.add_axes([0.92, 0.55, 0.02, 0.35])  # [left, bottom, width, height]
cbar1 = fig.colorbar(im1, cax=cbar_ax1)
cbar1.set_label('Epsilon')

# 第二行colorbar（右下角）
cbar_ax2 = fig.add_axes([0.92, 0.1, 0.02, 0.35])
cbar2 = fig.colorbar(im2, cax=cbar_ax2)
cbar2.set_label('Sigma (mS/m)')

plt.subplots_adjust(right=0.9, wspace=0.3, hspace=0.3)
plt.show()
