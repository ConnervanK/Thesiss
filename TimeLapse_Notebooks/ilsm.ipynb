# %% [markdown]
# # 19. Image Domain Least-squares migration
# Seismic migration is the process by which seismic data are manipulated to create
# an image of the subsurface reflectivity.
#
# In one of the previous tutorials, we have seen how the process can be formulated
# as an inverse problem, which requires access to a demigration-migration engine.
# As performing repeated migrations and demigrations can be very expensive, an
# alternative approach to obtain accurate and high-resolution estimate of the
# subsurface reflectivity has emerged under the name of image-domain least-squares
# migration.
#
# In image-domain least-squares migration, we identify a direct, linear link between
# the migrated image $\mathbf{m}$ and the sought after
# reflectivity $\mathbf{r}$, namely:
#
# \begin{align}\mathbf{m} = \mathbf{H} \mathbf{r}\end{align}
#
# Here $\mathbf{H}$ is the Hessian, which can be written as:
#
# \begin{align}\mathbf{H} = \mathbf{L}^H \mathbf{L}\end{align}
#
# where $\mathbf{L}$ is the demigration operator, whilst its adjoint
# $\mathbf{L}^H$ is the migration operator. In other words, we say that the
# migrated image can be seen as the result of a pair of demigration/migration of
# the reflectivity.
#
# Whilst there exists different ways to estimate $\mathbf{H}$, the approach
# that we will be using here entails applying demigration and migration to a special
# reflectivity model composed of regularly space scatterers. What we obtain is the
# spatially-varying impulse response of the migration operator, where each filter is
# also usually referred to as local point spread function (PSF).
#
# Once these PSFs are computed (an operation that requires one migration and one
# demigration, much cheaper than what we do in LSM), the migrated image can be deconvolved
# using the :py:class:`pylops.signalprocessing.NonStationaryConvolve2D` operator.

# %%
import matplotlib.pyplot as plt
import numpy as np

import pylops

plt.close("all")
np.random.seed(0)

# %% [markdown]
# To start we create a simple model with 2 interfaces (the same we used in
# the LSM tutorial) and our PSF model with regularly spaced scatteres

# %%
# Velocity Model
nx, nz = 81, 60
dx, dz = 4, 4
x, z = np.arange(nx) * dx, np.arange(nz) * dz
v0 = 1000  # initial velocity
kv = 0.0  # gradient
vel = np.outer(np.ones(nx), v0 + kv * z)

# Reflectivity Model
refl = np.zeros((nx, nz))
refl[:, 30] = -1
refl[:, 50] = 0.5

# PSF Reflectivity Model
psfrefl = np.zeros((nx, nz))
psfin = (10, 15)
psfend = (-10, -5)
psfj = (30, 30)

psfx = np.arange(psfin[0], nx + psfend[0], psfj[0])
psfz = np.arange(psfin[1], nz + psfend[1], psfj[1])
Psfx, Psfz = np.meshgrid(psfx, psfz, indexing="ij")
psfrefl[psfin[0] : psfend[0] : psfj[0], psfin[1] : psfend[-1] : psfj[-1]] = 1

# Receivers
nr = 51
rx = np.linspace(10 * dx, (nx - 10) * dx, nr)
rz = 20 * np.ones(nr)
recs = np.vstack((rx, rz))
dr = recs[0, 1] - recs[0, 0]

# Sources
ns = 51
sx = np.linspace(dx * 10, (nx - 10) * dx, ns)
sz = 10 * np.ones(ns)
sources = np.vstack((sx, sz))
ds = sources[0, 1] - sources[0, 0]

fig, axs = plt.subplots(1, 3, sharey=True, figsize=(10, 5))
axs[0].imshow(vel.T, cmap="summer", extent=(x[0], x[-1], z[-1], z[0]))
axs[0].scatter(recs[0], recs[1], marker="v", s=150, c="b", edgecolors="k")
axs[0].scatter(sources[0], sources[1], marker="*", s=150, c="r", edgecolors="k")
axs[0].axis("tight")
axs[0].set_xlabel("x [m]"), axs[0].set_ylabel("z [m]")
axs[0].set_title("Velocity")
axs[0].set_xlim(x[0], x[-1])

axs[1].imshow(refl.T, cmap="gray", extent=(x[0], x[-1], z[-1], z[0]))
axs[1].scatter(recs[0], recs[1], marker="v", s=150, c="b", edgecolors="k")
axs[1].scatter(sources[0], sources[1], marker="*", s=150, c="r", edgecolors="k")
axs[1].axis("tight")
axs[1].set_xlabel("x [m]")
axs[1].set_title("Reflectivity")
axs[1].set_xlim(x[0], x[-1])

axs[2].imshow(psfrefl.T, cmap="gray_r", extent=(x[0], x[-1], z[-1], z[0]))
axs[2].scatter(recs[0], recs[1], marker="v", s=150, c="b", edgecolors="k")
axs[2].scatter(sources[0], sources[1], marker="*", s=150, c="r", edgecolors="k")
axs[2].axis("tight")
axs[2].set_xlabel("x [m]")
axs[2].set_title("PSF Reflectivity")
axs[2].set_xlim(x[0], x[-1])
plt.tight_layout()

# %% [markdown]
# We can now create our Kirchhoff modelling object which we will use to model
# and migrate the data, as well as to model and migrate the PSF model.

# %%
nt = 151
dt = 0.004
t = np.arange(nt) * dt
wav, wavt, wavc = pylops.utils.wavelets.ricker(t[:41], f0=20)

kop = pylops.waveeqprocessing.Kirchhoff(
    z,
    x,
    t,
    sources,
    recs,
    v0,
    wav,
    wavc,
    mode="analytic",
    dynamic=False,
    wavfilter=True,
    engine="numba",
)
kopdyn = pylops.waveeqprocessing.Kirchhoff(
    z,
    x,
    t,
    sources,
    recs,
    v0,
    wav,
    wavc,
    mode="analytic",
    dynamic=True,
    wavfilter=True,
    aperture=2,
    angleaperture=50,
    engine="numba",
)

d = kop @ refl
mmig = kopdyn.H @ d

dpsf = kop @ psfrefl
mmigpsf = kopdyn.H @ dpsf

fig, axs = plt.subplots(1, 2, figsize=(10, 6))
axs[0].imshow(
    dpsf[ns // 2, :, :].T,
    extent=(rx[0], rx[-1], t[-1], t[0]),
    cmap="gray",
    vmin=-1e1,
    vmax=1e1,
)
axs[0].axis("tight")
axs[0].set_xlabel("x [m]"), axs[0].set_ylabel("t [m]")
axs[0].set_title(r"$d_{psf}$")
axs[1].imshow(
    mmigpsf.T, cmap="gray", extent=(x[0], x[-1], z[-1], z[0]), vmin=-5e0, vmax=5e0
)
axs[1].scatter(Psfx.ravel() * dx, Psfz.ravel() * dz, c="r")
axs[1].set_xlabel("x [m]"), axs[1].set_ylabel("z [m]")
axs[1].set_title(r"$m_{psf}$")
axs[1].axis("tight")
plt.tight_layout()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16364\2417894697.py:6: FutureWarning: A new implementation of Kirchhoff is provided in v2.1.0. This currently affects only the inner working of the operator, end-users can continue using the operator in the same way. Nevertheless, it is now recommended to provide the variables trav (and amp) as a tuples containing the traveltime (and amplitude) tables for sources and receivers separately. This behaviour will eventually become default in version v3.0.0.
#   kop = pylops.waveeqprocessing.Kirchhoff(
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16364\2417894697.py:20: FutureWarning: A new implementation of Kirchhoff is provided in v2.1.0. This currently affects only the inner working of the operator, end-users can continue using the operator in the same way. Nevertheless, it is now recommended to provide the variables trav (and amp) as a tuples containing the traveltime (and amplitude) tables for sources and receivers separately. This behaviour will eventually become default in version v3.0.0.
#   kopdyn = pylops.waveeqprocessing.Kirchhoff(
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16364\2417894697.py:20: UserWarning: Aperture is currently defined as ratio of offset over depth, and may be not ideal for highly heterogeneous media
#   kopdyn = pylops.waveeqprocessing.Kirchhoff(
# c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\dispatcher.py:536: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\cudadrv\nvvm.py:139, in NVVM.__new__(cls)
#     138 try:
# --> 139     inst.driver = open_cudalib('nvvm')
#     140 except OSError as e:
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\cudadrv\libs.py:65, in open_cudalib(lib)
#      64 path = get_cudalib(lib)
# ---> 65 return ctypes.CDLL(path)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\ctypes\__init__.py:361, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     359     name = _os.fspath(name)
# --> 361 self._handle = self._load_library(name, mode, handle, winmode)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\ctypes\__init__.py:379, in CDLL._load_library(self, name, mode, handle, winmode)
#     378     return handle
# --> 379 return _LoadLibrary(self._name, winmode)
#
# FileNotFoundError: Could not find module 'nvvm.dll' (or one of its dependencies). Try using the full path with constructor syntax.
#
# During handling of the above exception, another exception occurred:
#
# NvvmSupportError                          Traceback (most recent call last)
# Cell In[7], line 38
#      20 kopdyn = pylops.waveeqprocessing.Kirchhoff(
#      21     z,
#      22     x,
#    (...)     34     engine="cuda",
#      35 )
#      37 d = kop @ refl
# ---> 38 mmig = kopdyn.H @ d
#      40 dpsf = kop @ psfrefl
#      41 mmigpsf = kopdyn.H @ dpsf
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\linearoperator.py:334, in LinearOperator.__matmul__(self, other)
#     332     msg = "Scalar not allowed, use * instead"
#     333     raise ValueError(msg)
# --> 334 return self.__mul__(other)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\linearoperator.py:328, in LinearOperator.__mul__(self, x)
#     327 def __mul__(self, x: float | LinearOperator) -> LinearOperator:
# --> 328     return self.dot(x)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\linearoperator.py:704, in LinearOperator.dot(self, x)
#     702     x = x.reshape((-1, x.shape[-1]))
#     703 if x.ndim == 1:
# --> 704     y = self.matvec(x)
#     705     if (
#     706         is_dims_shaped
#     707         and not self.forceflat
#     708         and get_ndarray_multiplication()
#     709     ):
#     710         y = y.reshape(self.dimsd)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\utils\decorators.py:194, in count.<locals>.decorator.<locals>.wrapper(self, x)
#     191 @wraps(f)
#     192 def wrapper(self, x):
#     193     # perform operation
# --> 194     y = f(self, x)
#     195     # increase count of the associated operation
#     196     if fwd:
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\linearoperator.py:538, in LinearOperator.matvec(self, x)
#     535     msg = f"Dimension mismatch. Got {x.shape}, but expected ({N},) or ({N}, 1)."
#     536     raise ValueError(msg)
# --> 538 y = self._matvec(x)
#     540 if x.ndim == 1:
#     541     y = y.reshape(M)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\linearoperator.py:1398, in _AdjointLinearOperator._matvec(self, x)
#    1397 def _matvec(self, x: NDArray) -> NDArray:
# -> 1398     return self.A._rmatvec(x)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\utils\decorators.py:146, in reshaped.<locals>.decorator.<locals>.wrapper(self, x)
#     144 if swapaxis:
#     145     x = x.swapaxes(self.axis, axis)
# --> 146 y = f(self, x)
#     147 if swapaxis:
#     148     y = y.swapaxes(self.axis, axis)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\waveeqprocessing\kirchhoff.py:1217, in Kirchhoff._rmatvec(self, x)
#    1214 elif not self.travsrcrec:
#    1215     inputs = (x, y, self.nsnr, self.nt, self.ni, self.itrav, self.travd)
# -> 1217 y = self._kirch_rmatvec(*inputs)
#    1218 return y
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\waveeqprocessing\_kirchhoff_cuda.py:485, in _KirchhoffCudaHelper._rmatvec_cuda(self, *inputs)
#     468 """Adjoint with dispatching to appropriate CUDA kernels.
#     469
#     470 This method selects the appropriate kernel to execute based on the
#    (...)    482
#     483 """
#     484 if self.dynamic:
# --> 485     y_d = self._call_dynamic("_rmatvec", *inputs)
#     486 else:
#     487     y_d = self._call_kinematic("_rmatvec", *inputs)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\pylops\waveeqprocessing\_kirchhoff_cuda.py:413, in _KirchhoffCudaHelper._call_dynamic(self, opt, *inputs)
#     386     self._ampsrcrec_kirch_matvec_cuda[
#     387         self.num_blocks, self.num_threads_per_blocks
#     388     ](
#    (...)    410         angles_recs_d,
#     411     )
#     412 elif opt == "_rmatvec":
# --> 413     self._ampsrcrec_kirch_rmatvec_cuda[
#     414         self.num_blocks, self.num_threads_per_blocks
#     415     ](
#     416         x_d,
#     417         y_d,
#     418         ns_d,
#     419         nr_d,
#     420         nt_d,
#     421         ni_d,
#     422         dt_d,
#     423         vel_d,
#     424         trav_srcs_d,
#     425         trav_recs_d,
#     426         amp_srcs_d,
#     427         amp_recs_d,
#     428         aperturemin_d,
#     429         aperturemax_d,
#     430         aperturetap_d,
#     431         nz_d,
#     432         six_d,
#     433         rix_d,
#     434         angleaperturemin_d,
#     435         angleaperturemax_d,
#     436         angles_srcs_d,
#     437         angles_recs_d,
#     438     )
#     439 cuda.synchronize()
#     441 return y_d
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\dispatcher.py:539, in _LaunchConfiguration.__call__(self, *args)
#     538 def __call__(self, *args):
# --> 539     return self.dispatcher.call(args, self.griddim, self.blockdim,
#     540                                 self.stream, self.sharedmem)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\dispatcher.py:681, in CUDADispatcher.call(self, args, griddim, blockdim, stream, sharedmem)
#     679     kernel = next(iter(self.overloads.values()))
#     680 else:
# --> 681     kernel = _dispatcher.Dispatcher._cuda_call(self, *args)
#     683 kernel.launch(args, griddim, blockdim, stream, sharedmem)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\dispatcher.py:689, in CUDADispatcher._compile_for_args(self, *args, **kws)
#     687 assert not kws
#     688 argtypes = [self.typeof_pyval(a) for a in args]
# --> 689 return self.compile(tuple(argtypes))
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\dispatcher.py:932, in CUDADispatcher.compile(self, sig)
#     929 if not self._can_compile:
#     930     raise RuntimeError("Compilation disabled")
# --> 932 kernel = _Kernel(self.py_func, argtypes, **self.targetoptions)
#     933 # We call bind to force codegen, so that there is a cubin to cache
#     934 kernel.bind()
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\dispatcher.py:83, in _Kernel.__init__(self, py_func, argtypes, link, debug, lineinfo, inline, fastmath, extensions, max_registers, opt, device)
#      77 nvvm_options = {
#      78     'fastmath': fastmath,
#      79     'opt': 3 if opt else 0
#      80 }
#      82 cc = get_current_device().compute_capability
# ---> 83 cres = compile_cuda(self.py_func, types.void, self.argtypes,
#      84                     debug=self.debug,
#      85                     lineinfo=lineinfo,
#      86                     inline=inline,
#      87                     fastmath=fastmath,
#      88                     nvvm_options=nvvm_options,
#      89                     cc=cc)
#      90 tgt_ctx = cres.target_context
#      91 code = self.py_func.__code__
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\compiler.py:196, in compile_cuda(pyfunc, return_type, args, debug, lineinfo, inline, fastmath, nvvm_options, cc)
#     194 from numba.core.target_extension import target_override
#     195 with target_override('cuda'):
# --> 196     cres = compiler.compile_extra(typingctx=typingctx,
#     197                                   targetctx=targetctx,
#     198                                   func=pyfunc,
#     199                                   args=args,
#     200                                   return_type=return_type,
#     201                                   flags=flags,
#     202                                   locals={},
#     203                                   pipeline_class=CUDACompiler)
#     205 library = cres.library
#     206 library.finalize()
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler.py:481, in CompilerBase._compile_core(self)
#     479 except Exception as e:
#     480     if not isinstance(e, errors.NumbaError):
# --> 481         raise e
#     482     self.state.status.fail_reason = e
#     483     if is_final_pipeline:
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler_machinery.py:363, in PassManager.run(self, state)
#     361 except Exception as e:
#     362     if not isinstance(e, errors.NumbaError):
# --> 363         raise e
#     364     msg = "Failed in %s mode pipeline (step: %s)" % \
#     365         (self.pipeline_name, pass_desc)
#     366     patched_exception = self._patch_error(msg, e)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\typed_passes.py:470, in BaseNativeLowering.run_pass(self, state)
#     463 fndesc = \
#     464     funcdesc.PythonFunctionDescriptor.from_specialized_function(
#     465         interp, typemap, restype, calltypes,
#     466         mangler=targetctx.mangler, inline=flags.forceinline,
#     467         noalias=flags.noalias, abi_tags=[flags.get_mangle_string()])
#     469 with targetctx.push_code_library(library):
# --> 470     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     471                                 metadata=metadata)
#     472     lower.lower()
#     473     if not flags.no_cpython_wrapper:
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\lowering.py:40, in BaseLower.__init__(self, context, library, fndesc, func_ir, metadata)
#      37 self.flags = targetconfig.ConfigStack.top_or_none()
#      39 # Initialize LLVM
# ---> 40 self.module = self.library.create_ir_module(self.fndesc.unique_name)
#      42 # Python execution environment (will be available to the compiled
#      43 # function).
#      44 self.env = Environment.from_fndesc(self.fndesc)
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\core\codegen.py:576, in CodeLibrary.create_ir_module(self, name)
#     572 """
#     573 Create an LLVM IR module for use by this library.
#     574 """
#     575 self._raise_if_finalized()
# --> 576 ir_module = self._codegen._create_empty_module(name)
#     577 return ir_module
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\codegen.py:365, in JITCUDACodegen._create_empty_module(self, name)
#     363 ir_module = ir.Module(name)
#     364 ir_module.triple = CUDA_TRIPLE
# --> 365 ir_module.data_layout = nvvm.NVVM().data_layout
#     366 nvvm.add_ir_version(ir_module)
#     367 return ir_module
#
# File c:\Users\Administrator\miniconda3\envs\gprMax\Lib\site-packages\numba\cuda\cudadrv\nvvm.py:144, in NVVM.__new__(cls)
#     141     cls.__INSTANCE = None
#     142     errmsg = ("libNVVM cannot be found. Do `conda install "
#     143               "cudatoolkit`:\n%s")
# --> 144     raise NvvmSupportError(errmsg % e)
#     146 # Find & populate functions
#     147 for name, proto in inst._PROTOTYPES.items():
#
# NvvmSupportError: libNVVM cannot be found. Do `conda install cudatoolkit`:
# Could not find module 'nvvm.dll' (or one of its dependencies). Try using the full path with constructor syntax.

# %% [markdown]
# We can now extract the local PSFs and create the 2-dimensional
# non-stationary filtering operator

# %%
psfsize = (21, 21)
psfs = np.zeros((len(psfx), len(psfz), *psfsize))

for ipx, px in enumerate(psfx):
    for ipz, pz in enumerate(psfz):
        psfs[ipx, ipz] = mmigpsf[
            int(px - psfsize[0] // 2) : int(px + psfsize[0] // 2 + 1),
            int(pz - psfsize[1] // 2) : int(pz + psfsize[1] // 2 + 1),
        ]

fig, axs = plt.subplots(2, 1, figsize=(10, 5))
axs[0].imshow(
    psfs[:, 0].reshape(len(psfx) * psfsize[0], psfsize[1]).T,
    cmap="gray",
    vmin=-5e0,
    vmax=5e0,
)
axs[0].set_title(r"$m_{psf}$ iz=0")
axs[0].axis("tight")
axs[1].imshow(
    psfs[:, 1].reshape(len(psfx) * psfsize[0], psfsize[1]).T,
    cmap="gray",
    vmin=-5e0,
    vmax=5e0,
)
axs[1].set_title(r"$m_{psf}$ iz=1")
axs[1].axis("tight")
plt.tight_layout()

Cop = pylops.signalprocessing.NonStationaryConvolve2D(
    hs=psfs, ihx=psfx, ihz=psfz, dims=(nx, nz), engine="numba"
)

mmigpsf = Cop @ refl

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(
    mmig.T, cmap="gray", extent=(x[0], x[-1], z[-1], z[0]), vmin=-5e1, vmax=5e1
)
axs[0].set_title(r"$m_{mig}$")
axs[0].axis("tight")
axs[1].imshow(
    mmigpsf.T, cmap="gray", extent=(x[0], x[-1], z[-1], z[0]), vmin=-5e1, vmax=5e1
)
axs[1].set_title(r"$m_{mig, psf}$")
axs[1].axis("tight")
plt.tight_layout()

# %% [markdown]
# Finally, we are ready to invert our seismic image for its corresponding
# reflectivity using the :py:func:`pylops.optimization.sparsity.fista` solver.

# %%
minv, _, resnorm = pylops.optimization.sparsity.fista(
    Cop, mmig.ravel(), eps=1e2, niter=100, eigsdict=dict(niter=5, tol=1e-2), show=True
)
minv = minv.reshape(nx, nz)

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(
    mmig.T,
    cmap="gray",
    extent=(x[0], x[-1], z[-1], z[0]),
    vmin=-5e1,
    vmax=5e1,
)
axs[0].set_title(r"$m_{mig}$")
axs[0].axis("tight")
axs[1].imshow(minv.T, cmap="gray", extent=(x[0], x[-1], z[-1], z[0]), vmin=-1, vmax=1)
axs[1].set_title(r"$m_{inv}$")
axs[1].axis("tight")
plt.tight_layout()
# Out:
# FISTA (soft thresholding)
# --------------------------------------------------------------------------------
# The Operator Op has 4860 rows and 4860 cols
# eps = 1.000000e+02	tol = 1.000000e-10	niter = 100
# alpha = 1.038917e-05	thresh = 5.194586e-04
# --------------------------------------------------------------------------------
#    Itn          x[0]              r2norm     r12norm     xupdate
#      1      -0.0000e+00         2.018e+05   2.073e+05   1.782e+00
#      2      -0.0000e+00         1.336e+05   1.418e+05   9.512e-01
#      3      -0.0000e+00         8.959e+04   9.992e+04   8.278e-01
#      4      -0.0000e+00         6.273e+04   7.499e+04   7.312e-01
#      5      -0.0000e+00         5.030e+04   6.410e+04   6.544e-01
#      6      -0.0000e+00         3.365e+04   4.897e+04   6.072e-01
#      7      -0.0000e+00         2.509e+04   4.161e+04   5.314e-01
#      8      -0.0000e+00         2.042e+04   3.786e+04   4.593e-01
#      9      -0.0000e+00         1.873e+04   3.698e+04   4.044e-01
#     10      -0.0000e+00         1.186e+04   3.079e+04   3.590e-01
#     11      -0.0000e+00         1.042e+04   3.000e+04   3.309e-01
#     21       0.0000e+00         3.896e+03   2.666e+04   1.986e-01
#     31      -0.0000e+00         2.609e+03   2.394e+04   1.333e-01
#     41      -0.0000e+00         2.725e+03   2.285e+04   1.669e-01
#     51      -0.0000e+00         3.215e+03   2.204e+04   1.413e-01
#     61      -0.0000e+00         1.897e+03   1.943e+04   1.286e-01
#     71      -0.0000e+00         2.005e+03   1.892e+04   1.686e-01
#     81      -0.0000e+00         2.780e+03   1.935e+04   1.440e-01
#     91      -0.0000e+00         2.417e+03   1.836e+04   1.383e-01
#     92      -0.0000e+00         4.305e+03   2.027e+04   1.407e-01
#     93      -0.0000e+00         2.119e+03   1.805e+04   1.140e-01
#     94      -0.0000e+00         2.304e+03   1.818e+04   1.125e-01
#     95      -0.0000e+00         1.659e+03   1.748e+04   1.131e-01
#     96      -0.0000e+00         1.107e+03   1.690e+04   1.194e-01
#     97      -0.0000e+00         1.266e+03   1.705e+04   1.219e-01
#     98      -0.0000e+00         1.954e+03   1.775e+04   1.299e-01
#     99      -0.0000e+00         1.895e+03   1.766e+04   1.145e-01
#    100      -0.0000e+00         4.160e+03   1.991e+04   1.358e-01
#
# Iterations = 100        Total time (s) = 0.31
# --------------------------------------------------------------------------------

# %% [markdown]
# For a more advanced set of examples of both reflectivity and impedance
# image-domain LSM head over to this
# [notebook](https://github.com/mrava87/pylops_notebooks/blob/master/developement/LeastSquaresMigration_imagedomainmarmousi.ipynb).
